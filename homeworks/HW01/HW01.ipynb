# %%
import numpy as np

array = np.array([[1, 2, 3], [4, 5, 6]])
zeros = np.zeros(5)
ones = np.ones((2, 3))  # 2 строки, 3 столбца

# Атрибуты
print("shape", array.shape)
print("dtype", array.dtype)

print("[1, 2]", array[1, 2]) # индексирование
print("Подмассив\n", array[:1, 1:]) # подмассив через срез

array2 = np.array([[1, 2, 3], [4, 5, 6]])

sum_arrays = array + array2
mult_arrays = array * array2
print('mean', np.mean(array))
print('sum', np.sum(array))
print('max', np.max(array))
# Out:
# shape (2, 3)
# dtype int64
# [1, 2] 6
# Подмассив
#  [[2 3]]
# mean 3.5
# sum 21
# max 6
